# %% [markdown]
# # Сбор всех выделенных списков в один файл для работы

# %%
import pandas as pd
data = pd.read_csv('data_forprint.csv',encoding='utf8',index_col=None)
data= data.drop('Unnamed: 0',axis=1)
data.head(5)
# Out:
#    domain_id                                   domain_name  profearea_id  \
# 0          7  Информационные технологии, интернет, телеком           107
# 1          7  Информационные технологии, интернет, телеком            10
# 2          7  Информационные технологии, интернет, телеком            10
# 3          7  Информационные технологии, интернет, телеком            96
# 4          7  Информационные технологии, интернет, телеком            96
#
#              profearea_name     ad_id  \
# 0     Руководитель проектов  89187718
# 1                  Аналитик  90478414
# 2                  Аналитик  87797674
# 3  Программист, разработчик  90037853
# 4  Программист, разработчик  88043841
#
#                                                 name  \
# 0                Руководитель проектов сопровождения
# 1                                 Системный аналитик
# 2                                   Ведущий аналитик
# 3                       Программист Баз Данных (SQL)
# 4  Разработчик в команду надёжности и производите...
#
#                                         requirements  \
# 0  Умеете работать с рисками; \n Способны выстраи...
# 1  Опыт работы аналитиком от 2-х лет; \nОпыт прое...
# 2  Управление работой группы аналитиков на проект...
# 3  Уверенные знания SQL (MySQL) понимание плана в...
# 4  знаете С++ и многопоточное программирование; \...
#
#                                     responsibilities  \
# 0  Развивать бизнес-приложения и решения внешних ...
# 1  Возможность построить карьеру в ИТ банковской ...
# 2  Опыт проектирования систем различного класса в...
# 3  Оптимизация SQL-кода (план запроса, управление...
# 4  придумывать, разрабатывать и улучшать инструме...
#
#                                           conditions
# 0  Официальное оформление с первого рабочего дня;...
# 1  Опыт работы с CRM-системами (Microsoft Dynamic...
# 2  Никаких Дресс-кодов и стандартов \nКлассные ве...
# 3  Занятия в фитнес-клубе за счет компании; \nОпл...
# 4  знаете ROS; \nпрограммировали и анализировали ...

# %%
req = pd.read_csv('data_with_req_refined.csv',encoding='utf8',index_col=None)
req= req.drop('Unnamed: 0',axis=1)
req.head(5)
# Out:
#              profearea_name     ad_id  \
# 0     Руководитель проектов  89187718
# 1                  Аналитик  90478414
# 2                  Аналитик  87797674
# 3  Программист, разработчик  90037853
# 4  Программист, разработчик  88043841
#
#                                         requirements  \
# 0  Умеете работать с рисками; \n Способны выстраи...
# 1  Опыт работы аналитиком от 2-х лет; \nОпыт прое...
# 2  Управление работой группы аналитиков на проект...
# 3  Уверенные знания SQL (MySQL) понимание плана в...
# 4  знаете С++ и многопоточное программирование; \...
#
#                                 requirements_refined  \
# 0                               ['работать команде']
# 1  ['опыт' 'опыт работы' 'описания бизнес процесс...
# 2  ['разработка' 'работать команде' 'описания биз...
# 3  ['знание' 'понимание' 'sql' 'опыт работы' 'пон...
# 4  ['система' 'работать команде' 'опыт работы сис...
#
#                          req_idxs
# 0                  (array([15]),)
# 1  (array([ 0, 13, 25, 26, 35]),)
# 2      (array([ 7, 15, 25, 35]),)
# 3  (array([ 1,  2,  3, 13, 23]),)
# 4      (array([ 6, 15, 21, 48]),)

# %%
resp = pd.read_csv('data_with_resp_refined.csv',encoding='utf8',index_col=None)
resp= resp.drop('Unnamed: 0',axis=1)
resp.head(5)
# Out:
#              profearea_name     ad_id  \
# 0     Руководитель проектов  89187718
# 1                  Аналитик  90478414
# 2                  Аналитик  87797674
# 3  Программист, разработчик  90037853
# 4  Программист, разработчик  88043841
#
#                                     responsibilities  \
# 0  Развивать бизнес-приложения и решения внешних ...
# 1  Возможность построить карьеру в ИТ банковской ...
# 2  Опыт проектирования систем различного класса в...
# 3  Оптимизация SQL-кода (план запроса, управление...
# 4  придумывать, разрабатывать и улучшать инструме...
#
#                             responsibilities_refined  \
# 0  ['разработка' 'проект' 'решение' 'документация...
# 1  ['проект' 'решение' 'тестирование' 'участие' '...
# 2  ['разработка' 'проект' 'тестирование' 'взаимод...
# 3  ['разработка' 'взаимодействие' 'бизнес процесс...
# 4  ['разработка' 'тестирование' 'тестирование' 'у...
#
#                                 resp_idxs
# 0  (array([ 0,  1,  2,  7, 13, 16, 36]),)
# 1               (array([1, 2, 4, 5, 9]),)
# 2  (array([ 0,  1,  4,  6,  9, 17, 39]),)
# 3  (array([ 0,  6, 10, 17, 23, 26, 39]),)
# 4          (array([ 0,  4,  9, 13, 20]),)

# %%
cond = pd.read_csv('data_with_cond_refined.csv',encoding='utf8',index_col=None)
cond= cond.drop('Unnamed: 0',axis=1)
cond.head(5)
# Out:
#              profearea_name     ad_id  \
# 0     Руководитель проектов  89187718
# 1                  Аналитик  90478414
# 2                  Аналитик  87797674
# 3  Программист, разработчик  90037853
# 4  Программист, разработчик  88043841
#
#                                           conditions  \
# 0  Официальное оформление с первого рабочего дня;...
# 1  Опыт работы с CRM-системами (Microsoft Dynamic...
# 2  Никаких Дресс-кодов и стандартов \nКлассные ве...
# 3  Занятия в фитнес-клубе за счет компании; \nОпл...
# 4  знаете ROS; \nпрограммировали и анализировали ...
#
#                                   conditions_refined  \
# 0  ['официальный' 'компенсация' 'английский' 'it ...
# 1  ['работы 5 2' 'система грейдов систему' 'micro...
# 2  ['стоматологией' 'обучение' 'английский' 'it к...
# 3  ['обучение' 'it компании' 'гибкое начало' 'гиб...
# 4                                                 []
#
#                                            cond_idxs
# 0  (array([ 3,  4,  7, 14, 17, 20, 21, 22, 23, 24...
# 1                             (array([11, 22, 27]),)
# 2  (array([ 0,  2,  7, 14, 17, 18, 21, 28, 43, 48...
# 3                     (array([ 2, 14, 15, 20, 31]),)
# 4                          (array([], dtype=int64),)

# %%
data['req_refined']=req['requirements_refined']
data['req_idxs']=req['req_idxs']
data['resp_refined']=resp['responsibilities_refined']
data['resp_idxs']=resp['resp_idxs']
data['cond_refined']=cond['conditions_refined']
data['cond_idxs']=cond['cond_idxs']

# %%
data.to_csv('data_for_clustering.csv')
